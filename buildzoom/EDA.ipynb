# %%
import pandas as pd
import numpy as np

from statistics import median, mean

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, SnowballStemmer

pd.set_option('display.max_rows', 90000)
pd.set_option('display.max_columns', 50)

path = '/Users/nikhilsawal/OneDrive/machine_learning/data_science_case_studies/buildzoom/data/'

# %%
X_train = pd.read_table(path + 'train_data.csv')
X_test = pd.read_table(path + 'xtest_data.csv')
y_test = pd.read_csv(path + 'ytest_pred.csv')

# %%
X_train.head()
# Out:
#                                          licensetype          businessname  \
# 0                                                NaN               ADT LLC
# 1                                                NaN                   NaN
# 2                       SPECIALTY CONTRACTOR LICENSE         KLN MEDIA LLC
# 3  ELECTRICAL CONTRACTOR LICENSE, ELECTRICAL CONT...  OLSON ENERGY SERVICE
# 4                                                NaN                   NaN
#
#   legaldescription                                        description  \
# 0              NaN                INSTALL LOW VOLTAGE SECURITY SYSTEM
# 1              NaN  INSTALL (1) NON-ILLUMINATED WALL SIGN - PLAZA ...
# 2              NaN  INSTALL (1) NON-ILLUM ON-PREMISES WALL SIGN FO...
# 3              NaN             REPLACE OIL FURNACE W/ NEW GAS FURNACE
# 4              NaN  WIRE NEW SINGLE FAMILY RESIDENCE W/ 200 AMP SE...
#
#              type                 subtype job_value
# 0      ELECTRICAL              COMMERCIAL       NaN
# 1  SIGN/BILLBOARD              COMMERCIAL       NaN
# 2  SIGN/BILLBOARD              COMMERCIAL       NaN
# 3    MECHANICAL /  SINGLE FAMILY / DUPLEX       NaN
# 4      ELECTRICAL  SINGLE FAMILY / DUPLEX       NaN

# %%
X_train.dtypes
# Out:
# licensetype         object
# businessname        object
# legaldescription    object
# description         object
# type                object
# subtype             object
# job_value           object
# dtype: object

# %% [markdown]
# # License Type

# %%
print("Count of Uniques: ", len(X_train['licensetype'].unique()))
print("20 Unique values: ", X_train['licensetype'].unique()[:20])
# Out:
# Count of Uniques:  121
# 20 Unique values:  [nan 'SPECIALTY CONTRACTOR LICENSE'
#  'ELECTRICAL CONTRACTOR LICENSE, ELECTRICAL CONTRACTOR LICENSE, REFRIGERATION CONTRACTOR LIC., GENERAL'
#  'GENERAL CONTRACTOR LICENSE, REGIS. SIDE SEWER CONTRACTOR, GENERAL CONTRACTOR LICENSE'
#  'ELEVATOR CONTRACTOR LICENSE' 'ELECTRICAL CONTRACTOR LICENSE'
#  'GENERAL CONTRACTOR LICENSE, REFRIGERATION CONTRACTOR LIC.'
#  'ELECTRICAL CONTRACTOR LICENSE, REFRIGERATION CONTRACTOR LIC.'
#  'GENERAL CONTRACTOR LICENSE'
#  'ELECTRICAL CONTRACTOR LICENSE, GENERAL CONTRACTOR LICENSE'
#  'REFRIGERATION CONTRACTOR LIC., ELECTRICAL CONTRACTOR LICENSE, GENERAL CONTRACTOR LICENSE'
#  'GENERAL CONTRACTOR LICENSE, GENERAL CONTRACTOR LICENSE, REGIS. SIDE SEWER CONTRACTOR'
#  'GENERAL CONTRACTOR LICENSE, REGIS. SIDE SEWER CONTRACTOR'
#  'ELECTRICAL CONTRACTOR LICENSE, REFRIGERATION CONTRACTOR LIC., REGIS. SIDE SEWER CONTRACTOR'
#  'REFRIGERATION CONTRACTOR LIC., GENERAL CONTRACTOR LICENSE, ELECTRICAL CONTRACTOR LICENSE'
#  'ELECTRICAL CONTRACTOR LICENSE, REFRIGERATION CONTRACTOR LIC., GENERAL CONTRACTOR LICENSE, REFRIGERAT'
#  'ELECTRICAL CONTRACTOR LICENSE, ELECTRICAL CONTRACTOR LICENSE'
#  'REGIS. SIDE SEWER CONTRACTOR'
#  'ELECTRICAL CONTRACTOR LICENSE, REFRIGERATION CONTRACTOR LIC., SPECIALTY CONTRACTOR LICENSE'
#  'REGIS. SIDE SEWER CONTRACTOR, GENERAL CONTRACTOR LICENSE']

# %% [markdown]
# **NOTE:** From the output above we see that there are **121** unique values for `licensetype`. Also, each row is a combination of different licensetypes. For ex: the third row contains 4 licenses namely `ELECTRICAL CONTRACTOR LICENSE, ELECTRICAL CONTRACTOR LICENSE, REFRIGERATION CONTRACTOR LIC., GENERAL` where `ELECTRICAL CONTRACTOR LICENSE` is repeated twice, which just seems repeatative and needs to be cleaned up!!!
#
# **ALSO NOTE:** The license type `GENERAL CONTRACTOR LICENSE` appears in different formats like `GENERAL`, `GENERAL CONTRACTOR LICENSE` and so on. So, we are going to write a function `get_pattern()` that identifies these patterns and replaces them with the correct string, using another function `clean_license()`. In the example above, if we see `GENERAL`, we would want to replace it with `GENERAL CONTRACTOR LICENSE`.

# %%
import re

def get_uniques(df, col_name):
    
    uniques = []
    for i in df[col_name]:
        uniques += i
    return list(set(uniques))


def get_pattern(df):
    
    uniques = get_uniques(df, 'licensetype')
    unique = []
    for i in range(len(uniques)):
        
        pattern = re.compile('^'+uniques[i][:5]+'*')
        matches = []
        for index, license in enumerate(uniques):

            if pattern.search(license) is not None:
                matches.append(license)
        
        if matches not in unique:
            unique.append(matches)
        pass
    
    licenseList = []
    licenseDict = {}
    
    for licenses in unique:
        licenseList.append(licenses)
        licenseDict[max(licenses)] = licenses
    
    return licenseList

# %%
# license type
X_train.loc[:,'licensetype'] = X_train.loc[:,'licensetype'].fillna('None')
X_train.loc[:,'licensetype'] = X_train.loc[:,'licensetype'].apply(lambda x: x.split(', ')).apply(lambda x: list(set(x)))   
pattern = get_pattern(X_train)
print(pattern[0])
# Out:
# ['GENERAL CO', 'GENERAL C', 'GENERA', 'GENERAL CONTRACTOR LICENSE', 'GENERAL ', 'GENERAL CONT', 'GENERAL CONTRA', 'GENERAL']

# %% [markdown]
# The above output shows the different ways in which `GENERAL CONTRACTOR LICENSE` appears in `licensetype`. We will write a function `clean_license()` that replaces any other appearance like `'GENERAL CO', 'GENERAL C', 'GENERA'` with the complete license name `GENERAL CONTRACTOR LICENSE`.

# %%
# Clean licensetype
def clean_license(inp_list, reference):
    
    temp_list = []
    for i in inp_list:
        if i == 'None':
            temp_list.append(i)
        else:
            for j in reference:
                temp = []
                if i in j:
                    temp_list.append(max(j).lower().replace(" ", "_"))
                    break
    return temp_list

# %%
cleaned_license = [clean_license(item, pattern) for item in X_train['licensetype']]
print("Original Format: ", X_train['licensetype'][3],"\n")
print("Cleaned Format: ", cleaned_license[3])
# Out:
# Original Format:  ['ELECTRICAL CONTRACTOR LICENSE', 'GENERAL', 'REFRIGERATION CONTRACTOR LIC.']
#
# Cleaned Format:  ['electrical_contractor_license', 'general_contractor_license', 'refrigeration_contractor_lic.']

# %% [markdown]
# From the output above we can now see that `GENERAL` is replaced with `general_contractor_license`. Futher we will sort each of these lists in alphabetical order and concatenate each elements of the list which should reduce the number of uniques and make `OneHotEncoding` easy for our ML model to ingest

# %%
cleaned_license = ['-'.join(sorted(i)) for i in cleaned_license]
print("Formated String: ", cleaned_license[3])
X_train.loc[:,'licensetype'] = cleaned_license
# Out:
# Formated String:  electrical_contractor_license-general_contractor_license-refrigeration_contractor_lic.

# %%
print("Unique LicenseTypes: ", len(X_train['licensetype'].unique()))
# Out:
# Unique LicenseTypes:  48

# %% [markdown]
# **NOTE:** We have considerabely reduced the number of unique licensetypes from `121` to `48`.

# %% [markdown]
# # Business Name

# %%
print("Count of Uniques: ", len(X_train['businessname'].unique()))
print("", X_train['businessname'].unique())
# Out:
# Count of Uniques:  17398
#  ['ADT LLC' nan 'KLN MEDIA LLC' ... 'KRISTINE LOGAN'
#  'WESCO CONSTRUCTION DIVISION' 'FRED STAUSS']

# %%
def get_businessname(data, n):
    """Set top N businessnames as factor"""
    data['businessname'].fillna('None', inplace=True)
    temp = data['businessname'].value_counts().head(n).index.values
    top_n = [i.lower().replace(" ","_") if i in temp else 'Other' for i in data['businessname']]
    return top_n

# %%
X_train.loc[:,'businessname'] = get_businessname(X_train, 100)
print("Uniques: ", X_train['businessname'].unique())
print("Uniques: ", len(X_train['businessname'].unique()))
# Out:
# Uniques:  ['adt_llc' 'none' 'Other' 'olson_energy_service'
#  'metropolitan_sewer_service_llc' 'thyssenkrupp_elevator_corp'
#  'merit_mechanical_inc' 'boyer_electric_company_inc' 'kone_inc'
#  'blue_flame_llc' 'guardian_security_systems_inc'
#  'prime_electric_incorporated' 'active_engineering'
#  'reed_wright_htg_&_elec_co_inc' 'roto_rooter_services_company'
#  'titan_electric_inc' 'valley_elec_co_of_mtvernon_inc'
#  'evergreen_refrigeration_llc' "o'neill_plumbing_co"
#  "mr_rooter_plumbing_(sposari's)" 'kemly_electric_incorporated'
#  'otis_elevator_company' 'rescue_rooter_llc' 'schindler_elevator_company'
#  'north_star_electric_inc' 'sewer_friendly_llc'
#  'jim_dandy_sewer_services_inc' 'cardinal_heating_&_a/c_inc'
#  'adt_security_services_inc' 'allied_fire_&_security' 's_e_s_incorporated'
#  'c_&_r_electric_incorporated' 'pride_electric_incorporated' 'e_h_s_llc'
#  's_m_e_incorporated_of_seattle' 'm_m_comfort_systems'
#  'aces_four_construction_company' 'select_air_service'
#  'best_plumbing_group_llc' 'bowie_electric_svc&supply_inc'
#  'brennan_heating_&_a/c_llc' 'south_west_plbg_&_wtrhtrs_inc'
#  'beacon_plumbing_&_mechanical' 'washington_energy_svcs_(wesco)'
#  'cochran_incorporated' 'fischer_plumbing_co_inc,_the'
#  'ballard_natural_gas_svcs_inc' 'macdonald-miller_service_inc'
#  'cfm_heating_&_cooling' 'sequoyah_electric_llc'
#  'brennan_heating_company_inc' 'hermanson_company_llp'
#  'mckinstry_company_llc' "bob's_heating_&_a/c_inc"
#  'rossoe_energy_systems_inc' 'tube_art_displays_inc'
#  'nelson_electric_incorporated' 'veca_electric_company_inc'
#  'mckinstry_electric' 'major_electric_incorporated' 'as_you_wish_electric'
#  'greenwood_heating_and_ac' 'puget_sound_solar_llc'
#  'pipeline_industries_inc' 'snohomish_electric_inc'
#  'brinks_home_security_inc' 'evergreen_power_systems' 'holaday_parks_inc'
#  'sasco_electric' 'r_f_i_comm_&_security_systems'
#  'convergint_technologies_llc' 'seatac_electric_incorporated'
#  'protection_one_alarm_inc' 'emerald_aire_incorporated'
#  'holmes_electric_company' 'mauro_electric_inc' 'radford_electric_company'
#  'simplexgrinnell_lp' 'l_&_s_electrical_llc' 'provident_electric_inc'
#  'genesee_fuel_&_heating_co,_inc' 'u_of_w_building_permit'
#  'home_run_electric_llc' 'raymark_plumbing_&_sewer' 'techpros_llc'
#  "rob's_electric_incorporated" 'northwest_electric_&_solar_llc'
#  'meridian_center_electric_inc' 'seattle_school_district_(a&s)'
#  'endeavor_telecom_inc' 'boeing_commercial_airplane_grp' 'owner'
#  'burgess_design' 'playhouse_design_group' 'blueprint_services,_llc'
#  'julian_weber_arch_&_design_llc' 'sme_inc_of_seattle' 'novion_group_inc'
#  'wesco' 'jim_dandy_sewer_&_plumbing' 'evergreen_power_systems,_inc']
# Uniques:  101

# %% [markdown]
# # Legal Description

# %%
print("Count of Uniques: ", len(X_train['legaldescription'].unique()))
print("Uniques: ", X_train['legaldescription'].unique())
# Out:
# Count of Uniques:  14388
#  [nan
#  'LOT 3 TOGETHER WITH THE NORTH HALF OF LOT 4, BLOCK 17, LAWS 2ND ADDN'
#  'MARKET PLACE QUEEN ANNE CONDO, VOL 17, PAGE 8' ...
#  'PARCEL A, LBA #3005752'
#  "SLY 30' OF LOT 16, ALL OF LOTS 17 & 18 & NE 5.2' OF LOT 19, BLK 12, EAST PARK ADDITION"
#  'W 53 FT OF S 1/2, TR 2, BARTOS ACRE TRACTS']

# %% [markdown]
# Looking at the legal descriptions, we can make out that they are not very informative when it comes to making predictions. So we might just turn it into a boolean `has_LD`.

# %%
X_train.loc[:,'legaldescription'] = X_train['legaldescription'].fillna('None')
X_train.loc[:,'has_ld'] = [1 if i!='None' else 0 for i in X_train['legaldescription']]

# %% [markdown]
# # Description

# %%
print("Count of Uniques: ", len(X_train['description'].unique()))
print("Uniques: ", X_train['description'].unique()[:100])
# Out:
# Count of Uniques:  80143
# Uniques:  ['INSTALL LOW VOLTAGE SECURITY SYSTEM'
#  'INSTALL (1) NON-ILLUMINATED WALL SIGN - PLAZA GARIBALDI'
#  'INSTALL (1) NON-ILLUM ON-PREMISES WALL SIGN FOR &quot;PLAZA GARIBALDI&quot;'
#  'REPLACE OIL FURNACE W/ NEW GAS FURNACE'
#  'WIRE NEW SINGLE FAMILY RESIDENCE W/ 200 AMP SERVICE' 'REPAIR'
#  'Construct addition and alterations to existing single family residence, per plan.'
#  'ADDING CELLGUARD' 'Rebuild Letter' 'CAB INTERIOR UPGRADES'
#  '[TEMPORARY POWER. ]' 'Cancel per customer log 11-469'
#  'Expansion of existing minor communication facility consisting of removal and replacement of antennas and rooftop screening per plan.'
#  'Demo existing single family dwelling.' 'PREWIRE SECURITY SYSTEM'
#  'INSTALL TWO NEW 15 AMP CIRCUITS. REPLACE UNGROUNDED WIRING IN CRAWLSPACE.'
#  'NEW 200 AMP SERVICE' 'INSTALL HEAT PUMP TO SERVE BEDROOM & ATTIC'
#  'REROUTE SEWER & REPLACE DOWNSPOUT' 'Cancel per customer log 11-177'
#  'INSTALLING (2) DUCT SMOKE DETECTORS W/AUDIBLE TEST STATIONS, (2) T-STATS W/RETURN AIR DUCT SENSORS'
#  'F/A TI'
#  'Change of use from general retail sales & service to Medical office and construct interior, non-structural tenant improvements to existing mixed use building on the 2nd floor/occupy per plan.'
#  'WIRING FOR TI; POWER & LIGHTS. APE'
#  'Remove existing detached garage, established parking to remain, subject to field inspection.'
#  'REPLACE EXISTING BOILER' 'KITCHEN LIGHTING AND LIVINGROOM OUTLET'
#  'SOLAR POWERED PARKING PAY & DISPLAY UNIT.'
#  'AC POWERED PARKING PAY & DISPLAY UNIT.'
#  'Land Use Application to subdivide one parcel into two parcels of land. Proposed parcel sizes are: A) 3,645 sq. ft. and B) 1,800 sq. ft. Existing structures on proposed Parcel A and B to remain.'
#  'Construct 1-story addition to west side of existing single family residence per plan.'
#  'Construct deck to serve adjacent restaurant, per plan.'
#  'CLOSED AS INCOMPLETE - EXPIRED PERMIT. REPAIR EXISTING SANITARY SEWER & INSTALL PIPING FOR ADDITIONAL DOWNSPOUTS'
#  '(1) FURNACE CHANGE OUT & (1) NEW FURNACE IN SFR'
#  'RELOCATE METER BASE, WIRE REMODEL WITH ADDITIONS ADDED, AND NEW FURNACE. 9/30/09 BEW ADDED 200 AMP SERVICE'
#  'Establish an ADU in an existing single family residence per plan'
#  'INSTALL TEMP POWER POLE FOR CONSTRUCTION 1@001-125 AMP'
#  'INSTALL NEW GAS FURNACE'
#  'INSTALL ELECTRICAL WIRING FOR SECOND STORY REMODEL, INSTALL NEW SERVICE METER'
#  'Construct improvements to basement of single family residence per plan and subject to field inspection (STFI).'
#  '200 AMP SERVICE UPGRADE WITH SQUARE D QO 200 AMP PANEL. WIRE BASEMENT.'
#  'TEMP POWER POLE - RFR BDLG A/P #6179213' 'SIDE SEWER REPAIR'
#  'Construct full 2nd floor addition to existing songe family residence per plan.'
#  'ENTIRE HOUSE REMODEL, REWIRING ENTIRE ELECTRICAL SYSTEM'
#  'Construct dormer additions east side, enclose porch on NE corner, and alter portion of basement. Remove existing garage and provide off street parking, per floor plans and subject to field inspection, STFI.'
#  'WIRE KITCHEN REMODEL & SERVICE CHANGE. 5/6/08 JNL - ABOUT TO EXPIRE LETTER SENT. 5/26/09 BEW RENEWED'
#  'RECOVER EXISTING AWNING W/ GRAPHICS & INSTALL (3) ILLUM WALL SIGNS - VERIZON WIRELESS'
#  'UFER GROUND - REF #6118741' 'FIRE ALARM T.I.'
#  'Closed as Incomplete - Expired Permit Interior alterations to whole house, enclose back porch, no structural work, finish off basement to create bedrooms/bathrooms per plot plan and stfi'
#  'Construct addition to existing detached accessory garage per plot plan and stfi (revised 1/23/07)'
#  '200 AMP SERVICE UPGRADE. REPLACE EXISTING ZINSCO PANEL IN OUTBUILDING. INSTALL RECEPTACLES FOR COMPUTERS.'
#  'KITCHEN REMODEL REF: 6104340' 'KITCHEN, DINING ROOM LIVING ROOM REMODEL'
#  'WIRING FOR KITCHEN REMODEL'
#  'REPLACE RUBBER FLR W/NEW FOR KEY ARENA FREIGHT ELEVATOR'
#  'REPLACE GAS FURNACE IN SFR'
#  'REPLACE EXISITNG CIRCUIT. NEW DRYER CIRCUIT. REPLACE TWO EXISTING CIRCUITS'
#  'REMODEL AND UPDATE ELECTRICAL, SWITCH, OUTLET & LIGHTING'
#  'Closed as Incomplete - Expired Permit UNDERPIN 20 FEET OF NORTH FOUNDATION WALL, PER PLAN'
#  'SEWER REPAIR'
#  'ERECT TEMPORARY TENT OVER OUTDOOR SEATING AREA OF EXIST. RESTAURANT 11/27/04 THRU 5/27/05 PER PLANS LESSEE RESPONSIBLE FOR TENT STRUCTURAL INTEGRITY'
#  'WIRE ADDITION 2 BED ROOM AND 1 BATH.'
#  'UPGRADE TO A FULL 200 AMP SERVICE AND WIRE NEW ADDITION'
#  'SERVICE CHANGE 200 AMP. SFR' 'REWIRE TO KITCHEN REMODEL PROJECT. SFR'
#  'INSTALL NEW TYPE I COMMERCIAL HOOD IN FAST FOOD RESTAURANT PER PLAN'
#  'RENOVATION OF EXISTING RESTAURANT/ NEW SEATING/ ADA BTHMS/ PERFORMANCE PLATFORM/ NON-STRUCTURAL WALLS/ OCCUPY PER PLANS'
#  'CONSTRUCT ADDITION TO SECOND FLOOR OF SINGLE FAMILY RESIDENCE, PER PLAN'
#  'CONSTRUCT DORMER ADDITION TO EXISTING SINGLE FAMILY RESIDENCE ALL PER PLAN & SUBJECT TO FIELD INSPECTION.'
#  'SET UP FENCE AROUND PARKING AREA, ERECT CANOPIES AND LIGHTS FOR BEER GARDEN MARCH 2 - MARCH 7, 2000 PER PLOT PLAN'
#  'ESTABLISH TEMPORARY USE FOR BEER GARDEN FOR 30 DAY FROM 4/30/99 ENDING 5/30/99. PER PLOT PLAN SUBJECT TO FIELD INSPECTION.'
#  'ADD 6 FOOT RETAINING WALL IN THE REAR YARD TO REPLACE EXISTING FAILING RETAINING WALL'
#  'CONSTRUCT GROUND LEVEL ADDITION AND DECK ADDITION TO A SINGLE FAMILY RESIDENCE, PER PLOT PLAN & SUBJECT TO FIELD INSPECTION, STFI'
#  'DEMO EXISTING SINGLE FAMILY RESIDENCE ESTABLISH USE AS SINGLE FAMILY RESIDENCE CONSTRUCT ONE FAMILY DWELLING WITH ATTACHED GARAGE PER PLANS'
#  'INTERIOR ALTERATIONS DIVIDE 1 RETAIL SPACE INTO 2 SPACES PER PLAN'
#  'REMODEL SECOND FLOOR OF A SINGLE FAMILY RESIDENCE SUBJECT TO FIELD INSPECTION (STFI)'
#  'INTERIOR ALTERATIONS (KITCHEN REMODEL) TO SINGLE FAMILY RESIDENCE SUBJECT TO FIELD INSPECTION'
#  'REPLACE TWO (2) ROOFTOP UNITS IN KIND, SUBJECT TO FIELD INSPECTION (STFI)'
#  'ALTERATIONS TO LEVEL REAR OF EXISTING SFR & TO FINISH PORTION OF BASEMENT LEVEL FOR REC. ROOM SUBJECT TO FIELD INSPECTION (STFI)'
#  'CONSTRUCT AN EXTERIOR CONVENIENCE STAIRWAY, PER PLANS'
#  'ESTABLISH USE FOR RECORDS AS TWO SINGLE FAMILY RESIDENCES ON ONE SITE, PER PLANS'
#  'INSTALL HVAC IN EXISTING TAVERN PER PLAN'
#  'GRADE 2000 CU. YDS. OFF MATERIAL AND INSTALL SOIL NAILING SYSTEM/SHORING, PER PLANS'
#  'CONSTRUCT 1ST FLR BAY WINDOW ADDITION AND ALTERATIONS TO KITCHEN OF SINGLE FAMILY REISDENCE PER PLANS'
#  'ADD ONTO KITCHEN AND ADD DECK ALTER KITCHEN ALL PER PLANS'
#  'ADD DORMER TO EXISTING SFR,PER PLANS'
#  'KITCHEN & DECK ADDITION PER PLOT PLAN & STFI'
#  'RE-STRIPE PARKING LOT, PER PLANS'
#  'TO ESTABLISH SIDE WALK CAFE FOR THAI RESTAURANT'
#  'INSTALL (1) 7-DAY PROGRAMMABLE THERMOSTAT AND LOW VOLTAGE WIRING'
#  'Mechanical STFI - Adding 1 exhaust fan, 2 openings and 1 dryer vent to SPS McClure Middle School to floor 1 per plans.'
#  'Replace six heat pumps with new heat pumps'
#  '(PRIME JOB# 1139388) ADD SUB PANEL ONLY AND EMON DEMON METERING'
#  'INSTALL CLEAN OUT' 'Revision to decrease size of deck'
#  'REMODEL IN CONDO #302' 'REPLACING BAD FIRE ALARM CONTROL PANEL'
#  'Alterations to minor communication utility to replace cabinets and associated equipment on rooftop of existing office building, per plan']

# %% [markdown]
# Looking at some of the descriptions we can immediately make out that some of the terms may be specific to ELECTRICAL type and we might want to identify a way to account for these terms. We will be suing NLTK to compute the TF-IDF for these descriptions.

# %%
# Remove stopwords, non alphabetic characters


def nltk_description(data):
    
    # Split data to analyze patterns in Electrical type vs non
    stop_words = set(stopwords.words("english"))
    ps = PorterStemmer()
    num_pattern = re.compile(r'\s*[\W0-9\s]\s*')

    # Fill NaN in licensetype
    data.loc[:,'description'] = data.loc[:,'description'].fillna('None')

    sample = []

    for index, description in enumerate(data["description"]):
        
        words = word_tokenize(description)
        no_stops = [i for i in words if i.lower() not in stop_words]
        no_special_char = [ps.stem(num_pattern.sub("",i)) for i in no_stops if ps.stem(num_pattern.sub("",i)) != '']
        descrip = " ".join(i for i in no_special_char)
        sample.append(descrip)
        
    cv = TfidfVectorizer(min_df=1, stop_words='english')
    x_traincv = cv.fit_transform(sample)
    
    return x_traincv.toarray().sum(axis=1).reshape(data.shape[0])

# %%
X_train.loc[:,'tf-idf_description'] = nltk_description(X_train)
print(X_train['tf-idf_description'])
# Out:
# 0         1.944464
# 1         2.240490
# 2         2.620758
# 3         2.083272
# 4         2.602990
#             ...
# 100151    2.219222
# 100152    2.822032
# 100153    3.397444
# 100154    2.879694
# 100155    1.727000
# Name: tf-idf_description, Length: 100156, dtype: float64

# %% [markdown]
# # Type

# %%
print("Count of Uniques: ", len(X_train['type'].unique()))
print("Uniques: ", X_train['type'].unique())

# %% [markdown]
# # Subtype

# %%
print("Count of Uniques: ", len(X_train['subtype'].unique()))
print("Uniques: ", X_train['subtype'].unique())
# Out:
# Count of Uniques:  6
# Uniques:  ['COMMERCIAL' 'SINGLE FAMILY / DUPLEX' nan 'MULTIFAMILY' 'INDUSTRIAL'
#  'INSTITUTIONAL']

# %%
X_train['subtype'] = X_train['subtype'].fillna('None')
[i.lower().replace(" ", "_") for i in X_train['subtype']]
# Out:
# ['commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'none',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'multifamily',
#  'multifamily',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'none',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'single_family_/_duplex',
#  'commercial',
#  'industrial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'commercial',
#  'commercial',
#  'multifamily',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'none',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'multifamily',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'multifamily',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'institutional',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'multifamily',
#  'commercial',
#  'single_family_/_duplex',
#  'none',
#  'multifamily',
#  'none',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'none',
#  'commercial',
#  'commercial',
#  'none',
#  'institutional',
#  'none',
#  'single_family_/_duplex',
#  'none',
#  'institutional',
#  'multifamily',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'none',
#  'single_family_/_duplex',
#  'none',
#  'single_family_/_duplex',
#  'none',
#  'none',
#  'institutional',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'commercial',
#  'none',
#  'none',
#  'commercial',
#  'commercial',
#  'institutional',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'multifamily',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'none',
#  'single_family_/_duplex',
#  'none',
#  'multifamily',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'commercial',
#  'commercial',
#  'none',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'commercial',
#  'industrial',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'industrial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'none',
#  'industrial',
#  'none',
#  'commercial',
#  'none',
#  'commercial',
#  'none',
#  'multifamily',
#  'commercial',
#  'none',
#  'none',
#  'commercial',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'commercial',
#  'none',
#  'commercial',
#  'multifamily',
#  'commercial',
#  'none',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'none',
#  'multifamily',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'none',
#  'none',
#  'single_family_/_duplex',
#  'commercial',
#  'none',
#  'commercial',
#  'single_family_/_duplex',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'multifamily',
#  'none',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'institutional',
#  'none',
#  'none',
#  'commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'institutional',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'none',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'multifamily',
#  'commercial',
#  'commercial',
#  'commercial',
#  'none',
#  'commercial',
#  'none',
#  'none',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'none',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'commercial',
#  'none',
#  'none',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'institutional',
#  'single_family_/_duplex',
#  'none',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'industrial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'none',
#  'commercial',
#  'industrial',
#  'none',
#  'none',
#  'multifamily',
#  'commercial',
#  'commercial',
#  'commercial',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'multifamily',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'multifamily',
#  'multifamily',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'institutional',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'institutional',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'multifamily',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'none',
#  'multifamily',
#  'multifamily',
#  'institutional',
#  'single_family_/_duplex',
#  'institutional',
#  'none',
#  'single_family_/_duplex',
#  'institutional',
#  'single_family_/_duplex',
#  'none',
#  'single_family_/_duplex',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'multifamily',
#  'none',
#  'none',
#  'none',
#  'none',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'multifamily',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'multifamily',
#  'commercial',
#  'commercial',
#  'multifamily',
#  'commercial',
#  'multifamily',
#  'commercial',
#  'commercial',
#  'commercial',
#  'none',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'commercial',
#  'none',
#  'multifamily',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'single_family_/_duplex',
#  'none',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'commercial',
#  'none',
#  'single_family_/_duplex',
#  'none',
#  'commercial',
#  'multifamily',
#  'none',
#  'commercial',
#  'commercial',
#  'single_family_/_duplex',
#  'commercial',
#  'none',
#  'commercial',
#  'multifamily',
#  'commercial',
#  'commercial',
#  'none',
#  'commercial',
#  'none',
#  'commercial',
#  'commercial',
#  'commercial',
#  'none',
#  'commercial',
#  'none',
#  'none',
#  'commercial',
#  'none',
#  'commercial',
#  'none',
#  'commercial',
#  'none',
#  'commercial',
#  'none',
#  'commercial',
#  'single_family_/_duplex',
#  'none',
#  'none',
#  'multifamily',
#  'none',
#  'none',
#  'commercial',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'single_family_/_duplex',
#  'none',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'none',
#  'none',
#  'none',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'multifamily',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'multifamily',
#  'single_family_/_duplex',
#  'multifamily',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'single_family_/_duplex',
#  'single_family_/_duplex',
#  'none',
#  'single_family_/_duplex',
#  'multifamily',
#  'multifamily',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'industrial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'multifamily',
#  'multifamily',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  'none',
#  'none',
#  'commercial',
#  'commercial',
#  'commercial',
#  'commercial',
#  ...]

# %% [markdown]
# # Job value

# %%
print("Count of Uniques: ", len(X_train['job_value'].unique()))
print("Uniques: ", X_train['job_value'].unique())
# Out:
# Count of Uniques:  5132
# Uniques:  [nan '$250,000.00' '$45,000.00' ... '$321,743.00' '$164,848.00'
#  '$732,408.00']

# %%
cleaned_job_value = X_train['job_value'].apply(lambda x: float(str(x).replace('$', '').replace(',','')))
X_train.loc[:,'job_value'] = cleaned_job_value
X_train.loc[:,'job_value'] = X_train['job_value'].fillna(0.0)
X_train.head(200)
# Out:
#                                            licensetype  \
# 0                                                  NaN
# 1                                                  NaN
# 2                         SPECIALTY CONTRACTOR LICENSE
# 3    ELECTRICAL CONTRACTOR LICENSE, ELECTRICAL CONT...
# 4                                                  NaN
# 5    GENERAL CONTRACTOR LICENSE, REGIS. SIDE SEWER ...
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                          ELEVATOR CONTRACTOR LICENSE
# 10                       ELECTRICAL CONTRACTOR LICENSE
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                       ELECTRICAL CONTRACTOR LICENSE
# 16                       ELECTRICAL CONTRACTOR LICENSE
# 17                       ELECTRICAL CONTRACTOR LICENSE
# 18                                                 NaN
# 19                                                 NaN
# 20                       ELECTRICAL CONTRACTOR LICENSE
# 21                                                 NaN
# 22                                                 NaN
# 23                       ELECTRICAL CONTRACTOR LICENSE
# 24                                                 NaN
# 25   GENERAL CONTRACTOR LICENSE, REFRIGERATION CONT...
# 26                       ELECTRICAL CONTRACTOR LICENSE
# 27                       ELECTRICAL CONTRACTOR LICENSE
# 28                       ELECTRICAL CONTRACTOR LICENSE
# 29                                                 NaN
# 30                                                 NaN
# 31                                                 NaN
# 32                                                 NaN
# 33   ELECTRICAL CONTRACTOR LICENSE, REFRIGERATION C...
# 34                       ELECTRICAL CONTRACTOR LICENSE
# 35                                                 NaN
# 36                       ELECTRICAL CONTRACTOR LICENSE
# 37   GENERAL CONTRACTOR LICENSE, REFRIGERATION CONT...
# 38                       ELECTRICAL CONTRACTOR LICENSE
# 39                                                 NaN
# 40                       ELECTRICAL CONTRACTOR LICENSE
# 41                       ELECTRICAL CONTRACTOR LICENSE
# 42   GENERAL CONTRACTOR LICENSE, REGIS. SIDE SEWER ...
# 43                          GENERAL CONTRACTOR LICENSE
# 44                       ELECTRICAL CONTRACTOR LICENSE
# 45                                                 NaN
# 46                       ELECTRICAL CONTRACTOR LICENSE
# 47   ELECTRICAL CONTRACTOR LICENSE, GENERAL CONTRAC...
# 48                       ELECTRICAL CONTRACTOR LICENSE
# 49                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 52                       ELECTRICAL CONTRACTOR LICENSE
# 53                       ELECTRICAL CONTRACTOR LICENSE
# 54                       ELECTRICAL CONTRACTOR LICENSE
# 55                                                 NaN
# 56                         ELEVATOR CONTRACTOR LICENSE
# 57   REFRIGERATION CONTRACTOR LIC., ELECTRICAL CONT...
# 58                       ELECTRICAL CONTRACTOR LICENSE
# 59                       ELECTRICAL CONTRACTOR LICENSE
# 60                                                 NaN
# 61   GENERAL CONTRACTOR LICENSE, REGIS. SIDE SEWER ...
# 62                                                 NaN
# 63                                                 NaN
# 64                       ELECTRICAL CONTRACTOR LICENSE
# 65                       ELECTRICAL CONTRACTOR LICENSE
# 66                       ELECTRICAL CONTRACTOR LICENSE
# 67                       ELECTRICAL CONTRACTOR LICENSE
# 68                                                 NaN
# 69                                                 NaN
# 70                                                 NaN
# 71                                                 NaN
# 72                                                 NaN
# 73                                                 NaN
# 74                                                 NaN
# 75                                                 NaN
# 76                                                 NaN
# 77                                                 NaN
# 78                                                 NaN
# 79                                                 NaN
# 80                                                 NaN
# 81                                                 NaN
# 82                                                 NaN
# 83                                                 NaN
# 84                                                 NaN
# 85                                                 NaN
# 86                                                 NaN
# 87                                                 NaN
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91                                                 NaN
# 92                          GENERAL CONTRACTOR LICENSE
# 93                       ELECTRICAL CONTRACTOR LICENSE
# 94                                                 NaN
# 95                                                 NaN
# 96                       ELECTRICAL CONTRACTOR LICENSE
# 97   GENERAL CONTRACTOR LICENSE, GENERAL CONTRACTOR...
# 98                                                 NaN
# 99                       ELECTRICAL CONTRACTOR LICENSE
# 100                                                NaN
# 101                                                NaN
# 102                      ELECTRICAL CONTRACTOR LICENSE
# 103                         GENERAL CONTRACTOR LICENSE
# 104  ELECTRICAL CONTRACTOR LICENSE, ELECTRICAL CONT...
# 105  GENERAL CONTRACTOR LICENSE, REFRIGERATION CONT...
# 106                        ELEVATOR CONTRACTOR LICENSE
# 107                                                NaN
# 108                                                NaN
# 109                      ELECTRICAL CONTRACTOR LICENSE
# 110                      ELECTRICAL CONTRACTOR LICENSE
# 111                                                NaN
# 112  ELECTRICAL CONTRACTOR LICENSE, GENERAL CONTRAC...
# 113  GENERAL CONTRACTOR LICENSE, REGIS. SIDE SEWER ...
# 114                      ELECTRICAL CONTRACTOR LICENSE
# 115                                                NaN
# 116                      ELECTRICAL CONTRACTOR LICENSE
# 117                                                NaN
# 118                                                NaN
# 119  GENERAL CONTRACTOR LICENSE, REGIS. SIDE SEWER ...
# 120                                                NaN
# 121                                                NaN
# 122                      ELECTRICAL CONTRACTOR LICENSE
# 123                                                NaN
# 124  ELECTRICAL CONTRACTOR LICENSE, REFRIGERATION C...
# 125                      ELECTRICAL CONTRACTOR LICENSE
# 126  REFRIGERATION CONTRACTOR LIC., GENERAL CONTRAC...
# 127                                                NaN
# 128                      ELECTRICAL CONTRACTOR LICENSE
# 129                                                NaN
# 130                      ELECTRICAL CONTRACTOR LICENSE
# 131  GENERAL CONTRACTOR LICENSE, REGIS. SIDE SEWER ...
# 132                      ELECTRICAL CONTRACTOR LICENSE
# 133                                                NaN
# 134                                                NaN
# 135                      ELECTRICAL CONTRACTOR LICENSE
# 136                      ELECTRICAL CONTRACTOR LICENSE
# 137  ELECTRICAL CONTRACTOR LICENSE, REFRIGERATION C...
# 138  REFRIGERATION CONTRACTOR LIC., GENERAL CONTRAC...
# 139  ELECTRICAL CONTRACTOR LICENSE, ELECTRICAL CONT...
# 140                                                NaN
# 141                                                NaN
# 142  GENERAL CONTRACTOR LICENSE, REGIS. SIDE SEWER ...
# 143                                                NaN
# 144                       REGIS. SIDE SEWER CONTRACTOR
# 145  GENERAL CONTRACTOR LICENSE, REGIS. SIDE SEWER ...
# 146  ELECTRICAL CONTRACTOR LICENSE, GENERAL CONTRAC...
# 147                                                NaN
# 148                                                NaN
# 149                      ELECTRICAL CONTRACTOR LICENSE
# 150                                                NaN
# 151  ELECTRICAL CONTRACTOR LICENSE, GENERAL CONTRAC...
# 152                        ELEVATOR CONTRACTOR LICENSE
# 153                      ELECTRICAL CONTRACTOR LICENSE
# 154  GENERAL CONTRACTOR LICENSE, REGIS. SIDE SEWER ...
# 155                      ELECTRICAL CONTRACTOR LICENSE
# 156                        ELEVATOR CONTRACTOR LICENSE
# 157                                                NaN
# 158                      ELECTRICAL CONTRACTOR LICENSE
# 159                      ELECTRICAL CONTRACTOR LICENSE
# 160                                                NaN
# 161                                                NaN
# 162                        ELEVATOR CONTRACTOR LICENSE
# 163                         GENERAL CONTRACTOR LICENSE
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
# 167  GENERAL CONTRACTOR LICENSE, REGIS. SIDE SEWER ...
# 168                      ELECTRICAL CONTRACTOR LICENSE
# 169                                                NaN
# 170                                                NaN
# 171                      ELECTRICAL CONTRACTOR LICENSE
# 172                        ELEVATOR CONTRACTOR LICENSE
# 173  ELECTRICAL CONTRACTOR LICENSE, REFRIGERATION C...
# 174                                                NaN
# 175                                                NaN
# 176                      ELECTRICAL CONTRACTOR LICENSE
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
# 180                                                NaN
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
#                        businessname  \
# 0                           adt_llc
# 1                              none
# 2                             Other
# 3              olson_energy_service
# 4                              none
# 5    metropolitan_sewer_service_llc
# 6                              none
# 7                           adt_llc
# 8                              none
# 9        thyssenkrupp_elevator_corp
# 10                            Other
# 11                            Other
# 12                             none
# 13                             none
# 14                            Other
# 15                            Other
# 16                            Other
# 17                            Other
# 18                            Other
# 19                             none
# 20             merit_mechanical_inc
# 21                            Other
# 22                             none
# 23                            Other
# 24                             none
# 25                            Other
# 26       boyer_electric_company_inc
# 27                            Other
# 28                            Other
# 29                             none
# 30                             none
# 31                             none
# 32                            Other
# 33                            Other
# 34                            Other
# 35                             none
# 36                            Other
# 37                            Other
# 38                            Other
# 39                             none
# 40                            Other
# 41                            Other
# 42   metropolitan_sewer_service_llc
# 43                            Other
# 44                            Other
# 45                             none
# 46                            Other
# 47                            Other
# 48                            Other
# 49                            Other
# 50                             none
# 51                             none
# 52                            Other
# 53                            Other
# 54                            Other
# 55                             none
# 56                         kone_inc
# 57                   blue_flame_llc
# 58                            Other
# 59                            Other
# 60                             none
# 61   metropolitan_sewer_service_llc
# 62    guardian_security_systems_inc
# 63                             none
# 64                            Other
# 65                            Other
# 66                            Other
# 67                            Other
# 68                             none
# 69                             none
# 70                             none
# 71                             none
# 72                             none
# 73                             none
# 74                             none
# 75                             none
# 76                             none
# 77                             none
# 78                             none
# 79                             none
# 80                             none
# 81                             none
# 82                             none
# 83                             none
# 84                             none
# 85                             none
# 86                             none
# 87                             none
# 88                             none
# 89                             none
# 90                             none
# 91                             none
# 92                            Other
# 93                            Other
# 94                            Other
# 95                             none
# 96      prime_electric_incorporated
# 97                            Other
# 98                             none
# 99               active_engineering
# 100                           Other
# 101                           Other
# 102                           Other
# 103                           Other
# 104            olson_energy_service
# 105                           Other
# 106      thyssenkrupp_elevator_corp
# 107                            none
# 108                            none
# 109                           Other
# 110                           Other
# 111                            none
# 112   reed_wright_htg_&_elec_co_inc
# 113                           Other
# 114                           Other
# 115                            none
# 116              active_engineering
# 117                           Other
# 118                           Other
# 119                           Other
# 120                            none
# 121                            none
# 122                           Other
# 123                            none
# 124            merit_mechanical_inc
# 125                           Other
# 126                           Other
# 127                            none
# 128                           Other
# 129                            none
# 130                           Other
# 131    roto_rooter_services_company
# 132              titan_electric_inc
# 133                            none
# 134                            none
# 135                           Other
# 136  valley_elec_co_of_mtvernon_inc
# 137     evergreen_refrigeration_llc
# 138                           Other
# 139                           Other
# 140                            none
# 141                            none
# 142             o'neill_plumbing_co
# 143                            none
# 144                           Other
# 145  metropolitan_sewer_service_llc
# 146                           Other
# 147                            none
# 148                           Other
# 149                           Other
# 150                            none
# 151   reed_wright_htg_&_elec_co_inc
# 152      thyssenkrupp_elevator_corp
# 153                           Other
# 154  mr_rooter_plumbing_(sposari's)
# 155     kemly_electric_incorporated
# 156                           Other
# 157                            none
# 158                           Other
# 159                           Other
# 160                            none
# 161                           Other
# 162           otis_elevator_company
# 163                           Other
# 164                            none
# 165                           Other
# 166                           Other
# 167               rescue_rooter_llc
# 168                           Other
# 169                            none
# 170                            none
# 171                           Other
# 172      schindler_elevator_company
# 173                           Other
# 174                            none
# 175                            none
# 176                           Other
# 177                            none
# 178                            none
# 179                            none
# 180                            none
# 181                            none
# 182                            none
# 183                            none
# 184                            none
# 185                            none
# 186                            none
# 187                            none
# 188                            none
# 189                            none
# 190                            none
# 191                            none
# 192                            none
# 193                            none
# 194                            none
# 195                            none
# 196                            none
# 197                            none
# 198                            none
# 199                            none
#
#                                       legaldescription  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# 5                                                 None
# 6    LOT 3 TOGETHER WITH THE NORTH HALF OF LOT 4, B...
# 7                                                 None
# 8        MARKET PLACE QUEEN ANNE CONDO, VOL 17, PAGE 8
# 9                                                 None
# 10                                                None
# 11                                                None
# 12   198820-0055; S 110' OF E 120', BLOCK 24, D T D...
# 13                                                None
# 14                                                None
# 15                                                None
# 16                                                None
# 17                                                None
# 18                                                None
# 19   LOTS 11 & 12, BLK 48, LAWS 2ND ADDITION AKA: F...
# 20                                                None
# 21                                                None
# 22       MARKET PLACE QUEEN ANNE CONDO, VOL 17, PAGE 8
# 23                                                None
# 24                                                None
# 25                                                None
# 26                                                None
# 27                                                None
# 28                                                None
# 29                               PARCAL A, SP #3010940
# 30   E 80' OF S 10' OF LT 3, ALL OF LT 4, BLK 48, L...
# 31            LOT 12, BLOCK 33, D.T. DENNY'S HOME ADDN
# 32                                                None
# 33                                                None
# 34                                                None
# 35                          LOTS 104-105, DWIGHTS ADDN
# 36                                                None
# 37                                                None
# 38                                                None
# 39                                                None
# 40                                                None
# 41                                                None
# 42                                                None
# 43                       LOT 3, BLOCK 48, BIGELOWS ADD
# 44                                                None
# 45                                                None
# 46                                                None
# 47                                                None
# 48                                                None
# 49                                                None
# 50                                                None
# 51                                                None
# 52                                                None
# 53                                                None
# 54                                                None
# 55                                                None
# 56                                                None
# 57                                                None
# 58                                                None
# 59                                                None
# 60   LT 1, & BLK 9, PLEASANT RIDGE ADDITION & N 24'...
# 61                                                None
# 62                                                None
# 63                                                None
# 64                                                None
# 65                                                None
# 66                                                None
# 67                                                None
# 68                                                None
# 69                                                None
# 70                                                None
# 71                                                None
# 72                                                None
# 73                                                None
# 74                                                None
# 75                                                None
# 76                                                None
# 77                                                None
# 78                                                None
# 79                                                None
# 80                                                None
# 81                                                None
# 82                                                None
# 83                                                None
# 84                                                None
# 85                                                None
# 86                                                None
# 87                                                None
# 88                                                None
# 89                                                None
# 90                                                None
# 91                                                None
# 92                                                None
# 93                                                None
# 94                                                None
# 95                                                None
# 96                                                None
# 97                                                None
# 98                                                None
# 99                                                None
# 100                                               None
# 101  LTS 7 THRU 9, BLK 20, D.T.DENNY'S NORTH SEATTL...
# 102                                               None
# 103                                               None
# 104                                               None
# 105                                               None
# 106                                               None
# 107                                               None
# 108                                               None
# 109                                               None
# 110                                               None
# 111                                               None
# 112                                               None
# 113                                               None
# 114                                               None
# 115   515 First Avenue West (Condo), Vol 144 pgs 90-94
# 116                                               None
# 117                                               None
# 118  LOTS 1 THRU 6, BLK 15, D.T. DENNY'S NO. SEATTL...
# 119                                               None
# 120  THE N 28 FT OF LOT 15 & THE S 5 FT OF LOT 14, ...
# 121                                               None
# 122                                               None
# 123  LTS 6-8, 14-16, BLK 11, COVE ADDNTGW ALL OF BL...
# 124                                               None
# 125                                               None
# 126                                               None
# 127                                               None
# 128                                               None
# 129                                               None
# 130                                               None
# 131                                               None
# 132                                               None
# 133                                               None
# 134              LOTS 1 THRU 9, BLOCK 18, COMSTOCK ADD
# 135                                               None
# 136                                               None
# 137                                               None
# 138                                               None
# 139                                               None
# 140                                               None
# 141                                               None
# 142                                               None
# 143                                               None
# 144                                               None
# 145                                               None
# 146                                               None
# 147             CARRARA II CONDOS, VOL 170, PGS. 13-19
# 148  LOTS 1 THRU 6, BLK 15, D.T. DENNY'S NO. SEATTL...
# 149                                               None
# 150  LT 6, BLK 7, PLEASANT RIDGE ADD TGW S 5' OF VA...
# 151                                               None
# 152                                               None
# 153                                               None
# 154                                               None
# 155                                               None
# 156                                               None
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
# 161                                               None
# 162                                               None
# 163                                               None
# 164                                               None
# 165                                               None
# 166                                               None
# 167                                               None
# 168                                               None
# 169                                               None
# 170                                               None
# 171                                               None
# 172                                               None
# 173                                               None
# 174                                               None
# 175                                               None
# 176                                               None
# 177                                               None
# 178                                               None
# 179                                               None
# 180                                               None
# 181                                               None
# 182                                               None
# 183                                               None
# 184                                               None
# 185                                               None
# 186                                               None
# 187                                               None
# 188                                               None
# 189                                               None
# 190                                               None
# 191                                               None
# 192                                               None
# 193                                               None
# 194                                               None
# 195                                               None
# 196                                               None
# 197                                               None
# 198                                               None
# 199                                               None
#
#                                            description  \
# 0                  INSTALL LOW VOLTAGE SECURITY SYSTEM
# 1    INSTALL (1) NON-ILLUMINATED WALL SIGN - PLAZA ...
# 2    INSTALL (1) NON-ILLUM ON-PREMISES WALL SIGN FO...
# 3               REPLACE OIL FURNACE W/ NEW GAS FURNACE
# 4    WIRE NEW SINGLE FAMILY RESIDENCE W/ 200 AMP SE...
# 5                                               REPAIR
# 6    Construct addition and alterations to existing...
# 7                                     ADDING CELLGUARD
# 8                                       Rebuild Letter
# 9                                CAB INTERIOR UPGRADES
# 10                                 [TEMPORARY POWER. ]
# 11                      Cancel per customer log 11-469
# 12   Expansion of existing minor communication faci...
# 13               Demo existing single family dwelling.
# 14                             PREWIRE SECURITY SYSTEM
# 15   INSTALL TWO NEW 15 AMP CIRCUITS. REPLACE UNGRO...
# 16                                 NEW 200 AMP SERVICE
# 17          INSTALL HEAT PUMP TO SERVE BEDROOM & ATTIC
# 18                   REROUTE SEWER & REPLACE DOWNSPOUT
# 19                      Cancel per customer log 11-177
# 20   INSTALLING (2) DUCT SMOKE DETECTORS W/AUDIBLE ...
# 21                                              F/A TI
# 22   Change of use from general retail sales & serv...
# 23                  WIRING FOR TI; POWER & LIGHTS. APE
# 24   Remove existing detached garage, established p...
# 25                             REPLACE EXISTING BOILER
# 26              KITCHEN LIGHTING AND LIVINGROOM OUTLET
# 27           SOLAR POWERED PARKING PAY & DISPLAY UNIT.
# 28              AC POWERED PARKING PAY & DISPLAY UNIT.
# 29   Land Use Application to subdivide one parcel i...
# 30   Construct 1-story addition to west side of exi...
# 31   Construct deck to serve adjacent restaurant, p...
# 32   CLOSED AS INCOMPLETE - EXPIRED PERMIT. REPAIR ...
# 33     (1) FURNACE CHANGE OUT & (1) NEW FURNACE IN SFR
# 34   RELOCATE METER BASE, WIRE REMODEL WITH ADDITIO...
# 35   Establish an ADU in an existing single family ...
# 36   INSTALL TEMP POWER POLE FOR CONSTRUCTION 1@001...
# 37                             INSTALL NEW GAS FURNACE
# 38   INSTALL ELECTRICAL WIRING FOR SECOND STORY REM...
# 39   Construct improvements to basement of single f...
# 40   200 AMP SERVICE UPGRADE WITH SQUARE D QO 200 A...
# 41             TEMP POWER POLE - RFR BDLG A/P #6179213
# 42                                   SIDE SEWER REPAIR
# 43   Construct full 2nd floor addition to existing ...
# 44   ENTIRE HOUSE REMODEL, REWIRING ENTIRE ELECTRIC...
# 45   Construct dormer additions east side, enclose ...
# 46   WIRE KITCHEN REMODEL & SERVICE CHANGE. 5/6/08 ...
# 47   RECOVER EXISTING AWNING W/ GRAPHICS & INSTALL ...
# 48                          UFER GROUND - REF #6118741
# 49                                     FIRE ALARM T.I.
# 50   Closed as Incomplete - Expired Permit Interior...
# 51   Construct addition to existing detached access...
# 52   200 AMP SERVICE UPGRADE. REPLACE EXISTING ZINS...
# 53                        KITCHEN REMODEL REF: 6104340
# 54            KITCHEN, DINING ROOM LIVING ROOM REMODEL
# 55                          WIRING FOR KITCHEN REMODEL
# 56   REPLACE RUBBER FLR W/NEW FOR KEY ARENA FREIGHT...
# 57                          REPLACE GAS FURNACE IN SFR
# 58   REPLACE EXISITNG CIRCUIT. NEW DRYER CIRCUIT. R...
# 59   REMODEL AND UPDATE ELECTRICAL, SWITCH, OUTLET ...
# 60   Closed as Incomplete - Expired Permit UNDERPIN...
# 61                                        SEWER REPAIR
# 62                 INSTALL LOW VOLTAGE SECURITY SYSTEM
# 63   ERECT TEMPORARY TENT OVER OUTDOOR SEATING AREA...
# 64                WIRE ADDITION 2 BED ROOM AND 1 BATH.
# 65   UPGRADE TO A FULL 200 AMP SERVICE AND WIRE NEW...
# 66                         SERVICE CHANGE 200 AMP. SFR
# 67              REWIRE TO KITCHEN REMODEL PROJECT. SFR
# 68   INSTALL NEW TYPE I COMMERCIAL HOOD IN FAST FOO...
# 69   RENOVATION OF EXISTING RESTAURANT/ NEW SEATING...
# 70   CONSTRUCT ADDITION TO SECOND FLOOR OF SINGLE F...
# 71   CONSTRUCT DORMER ADDITION TO EXISTING SINGLE F...
# 72   SET UP FENCE AROUND PARKING AREA, ERECT CANOPI...
# 73   ESTABLISH TEMPORARY USE FOR BEER GARDEN FOR 30...
# 74   ADD 6 FOOT RETAINING WALL IN THE REAR YARD TO ...
# 75   CONSTRUCT GROUND LEVEL ADDITION AND DECK ADDIT...
# 76   DEMO EXISTING SINGLE FAMILY RESIDENCE ESTABLIS...
# 77   INTERIOR ALTERATIONS DIVIDE 1 RETAIL SPACE INT...
# 78   REMODEL SECOND FLOOR OF A SINGLE FAMILY RESIDE...
# 79   INTERIOR ALTERATIONS (KITCHEN REMODEL) TO SING...
# 80   REPLACE TWO (2) ROOFTOP UNITS IN KIND, SUBJECT...
# 81   ALTERATIONS TO LEVEL REAR OF EXISTING SFR & TO...
# 82   CONSTRUCT AN EXTERIOR CONVENIENCE STAIRWAY, PE...
# 83   ESTABLISH USE FOR RECORDS AS TWO SINGLE FAMILY...
# 84            INSTALL HVAC IN EXISTING TAVERN PER PLAN
# 85   GRADE 2000 CU. YDS. OFF MATERIAL AND INSTALL S...
# 86   CONSTRUCT 1ST FLR BAY WINDOW ADDITION AND ALTE...
# 87   ADD ONTO KITCHEN AND ADD DECK ALTER KITCHEN AL...
# 88                ADD DORMER TO EXISTING SFR,PER PLANS
# 89        KITCHEN & DECK ADDITION PER PLOT PLAN & STFI
# 90                    RE-STRIPE PARKING LOT, PER PLANS
# 91     TO ESTABLISH SIDE WALK CAFE FOR THAI RESTAURANT
# 92                                              REPAIR
# 93   INSTALL (1) 7-DAY PROGRAMMABLE THERMOSTAT AND ...
# 94   Mechanical STFI - Adding 1 exhaust fan, 2 open...
# 95          Replace six heat pumps with new heat pumps
# 96   (PRIME JOB# 1139388) ADD SUB PANEL ONLY AND EM...
# 97                                   INSTALL CLEAN OUT
# 98                   Revision to decrease size of deck
# 99                               REMODEL IN CONDO #302
# 100             REPLACING BAD FIRE ALARM CONTROL PANEL
# 101  Alterations to minor communication utility to ...
# 102  Closed without final inspection, no known life...
# 103                             Post Permit Sprinklers
# 104             REPLACE OIL FURNACE W/ NEW GAS FURNACE
# 105                                 BOILER REPLACEMENT
# 106  CONTROLLER, MACHINE, SHEAVES, GOVERNOR, CAR ST...
# 107  Connect 3 new supply grilles to existing air h...
# 108  Construct interior alterations to existing off...
# 109                     ADD CIRCUIT FOR SISTERN SYSTEM
# 110  REPLACE KNOB AND TUBE IN ATTIC SPACE. UPGRADE ...
# 111                             RELOCATING (5) T-STATS
# 112  REPLACE EXISTING PORTABLE HOT WATER BOILER WIT...
# 113                             SEWER REPAIR IN STREET
# 114       WIRE 2ND FLR ADDITION, INSTALL 70 AMP FEEDER
# 115  Alter office unit into 2 offices unit of 1st f...
# 116  ADD CIRCUITS FOR ROOFTOP CHILLER TO SERVE LIVI...
# 117   Relocate 35 diffusers and ductwork per plot plan
# 118  Blanket Permit for non-structural tenant impro...
# 119   REPAIR SEWER LINE. 8/26/09 BEW ADDED WORK IN ROW
# 120  Revision to revise scope of the top floor remo...
# 121                        RELOCATING (4) F/A SPEAKERS
# 122                             REWIRE OF EXISTING SFR
# 123  CLOSED AS INCOMPLETE - EXPIRED PERMIT. Constru...
# 124                   REPLACE EXISTING BOILER WITH NEW
# 125                   UPGRADE ELECTRICAL AND FA SYSTEM
# 126          REPLACE EXISTING GAS FURNACE WITH NEW 93%
# 127  UPDATE 125 AMP SERVICE BY REPLACING PANEL BOX,...
# 128  WIRE NEW GARAGE TO REPLACE EXISTING. REPLACE O...
# 129  Remove existing detached rear garage and const...
# 130  INSTALLING AUDIO/VIDEO, LIGHTING, SECURITY AND...
# 131                                  SIDE SEWER REPAIR
# 132  GET STARTED PERMIT FOR FIRE ALARM SYSTEM. REF ...
# 133  Alterations to existing (basement and stairs o...
# 134  Alter interior, new south entrance and skyligh...
# 135  Closed without final inspection, no known life...
# 136              INSTALLATION OF LOW VOLTAGE CONTROLS.
# 137  Relocate (5) existing diffusers, and minor duc...
# 138                               REPLACING BOILER B-1
# 139                  INSTALL HVAC/REFER CONTROL SYSTEM
# 140  Demolish existing single-family dwelling per p...
# 141  ADD 5 CAN LIGHTS FOR EXTERIOR PORCH; RELOCATE ...
# 142                INSTALLING 6 INCH C/O IN FRONT YARD
# 143  Porch additions to single family residence per...
# 144                               NEW SEWER & DRAINAGE
# 145                                             REPAIR
# 146  INSTALL NON-ILLUM MONUMENT ID SIGN - ST ANNE C...
# 147  REMOVE, REPAIR AND REPLACE DAMAGED SIDING, SHE...
# 148  Blanket Permit for interior non-structural alt...
# 149  RELOCATE 125A SERVICE & REMODEL TOP FLOOR. 7/2...
# 150  DEMOLITION OF DUPLEX. ESTABLISH USE AS TWO 2-U...
# 151                           INSTALL NEW STORAGE TANK
# 152            INSTALL NEW HYDRAULIC ELEVATOR - EU0334
# 153                WIRING OF COMMERCIAL T.I 2176 SQ FT
# 154                                  SIDE SEWER REPAIR
# 155  PROVIDE AND INSTALL 125 AMP SERVICE, PICKING U...
# 156                              TEMP OPERATING PERMIT
# 157  INSTALL NEW DUCTWORK FROM EXISTING FAN COIL UN...
# 158                  WIRE OFFICE, TI UNDER 2,500 SQ FT
# 159    INSTALL OUTLETS & LIGHTING FOR RESTAURANT SPACE
# 160  INITIAL TENANT IMPROVEMENTS TO PORTION OF EXIS...
# 161           INSTALL NEW SPRINKLER MONITORING SYSTEM.
# 162  60-DAY TEMPORARY OPERATING PERMIT. 10/2/03 JCB...
# 163                         REPLACE FURNACE & DUCTWORK
# 164     INSTALL SPRINKLERS IN EXISTING BLDG. PER PLANS
# 165                            AUTOMATIC CERTIFICATION
# 166  TELEPHONE CABLING FOR TRIBECA CONDOMINIUMS - T...
# 167                        REPAIR EXISTING SIDE SEWER.
# 168  ADDING (1) BEDROOM, (2) BATHROOMS, & REMODEL E...
# 169  CONSTRUCT DETACHED GARAGE ACCESSORY TO EXISTIN...
# 170                                               None
# 171                      WIRE SINGLE FAMILY RESIDENCE.
# 172                             INSTALL NEW ESCALLATOR
# 173  INSTALL NEW GAS FURNACE AND DUCTWORK IN NEW CO...
# 174  CHANGE OF USE FROM RETAIL TO MEDICAL SERVICE O...
# 175  RELOCATE 6 DIFFUSERS, REPLACE 20 RETURN AIR GR...
# 176  TELECOMMUNICATIONS UPGRADE - MCCLURE MIDDLE SC...
# 177  DUCTWORK AND DIFFUSERS FOR TENANT IMPROVEMENT ...
# 178  REMOVE ABANDONED DETACHED DRIVE-UP BANKING CAN...
# 179  INSTALL HVAC SYSTEM FOR CORRIDORS AND EXHAUST ...
# 180  FUTURE CONSTRUCION OF A MIXED-USE BLDG COMPRIS...
# 181  DEMOLITION OF 3 COMMERCIAL BUILDINGS FUTURE CO...
# 182  INTERIOR ALTERATIONS TO BASEMENT SPACES FOR CO...
# 183  TO ID 1(EXISTING 14 UNIT APT BLDG.) DEMOLISH 1...
# 184  CONSTRUCT 2-STORY ADDITION & DECK INTERIOR ALT...
# 185  REPLACE POOL HEATING & VENTILATING UNIT WITH N...
# 186  ALTERATIONS TO RESTROOM ON MAIN FLOOR & CONSTR...
# 187  ON MUP 8801566 CONSTRUCT 5-STORY HOTEL WITH PA...
# 188  CONSTRUCT RETAINING WALL ACC'Y TO SINGLE FAMIL...
# 189  INTERIOR ALTERATIONS TO FINISH BASEMENT OF SIN...
# 190  INSTALL (1) SUPPLY DIFF.,(5) RETURN AIR, RELOC...
# 191  CONSTRUCT DETACHED GARAGE ACCESSORY TO SINGLE ...
# 192  TO PORTION OF GARAGE FOR MOBILEPHONE EQUIPMENT...
# 193  ON MUP 8801566 CONSTRUCT 5-STORY HOTEL WITH PA...
# 194  BLANKET PERMIT-INTR NON-STRUCTURAL ALTERATION ...
# 195                CONSTRUCT RETAINING WALL, PER PLANS
# 196  REPLACE OLD PLASTER WITH NEW PLASTERBOARD AT I...
# 197  BLANKET PERMIT-INTR NON-STRUCTURAL ALTERATION ...
# 198               REPLACE ROOF SHEATHING OF SFR, STFI.
# 199  ENCLOSE REAR PORCH UNDER EXISTING ROOF ON SFR ...
#
#                                          type                 subtype  \
# 0                                  ELECTRICAL              COMMERCIAL
# 1                              SIGN/BILLBOARD              COMMERCIAL
# 2                              SIGN/BILLBOARD              COMMERCIAL
# 3                                MECHANICAL /  SINGLE FAMILY / DUPLEX
# 4                                  ELECTRICAL  SINGLE FAMILY / DUPLEX
# 5                                  SIDE SEWER  SINGLE FAMILY / DUPLEX
# 6       CONSTRUCTION / ADDITION OR ALTERATION  SINGLE FAMILY / DUPLEX
# 7                                  ELECTRICAL  SINGLE FAMILY / DUPLEX
# 8                                   LU POLICY                     NaN
# 9                                  CONVEYANCE                     NaN
# 10                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 11                                 ELECTRICAL              COMMERCIAL
# 12      CONSTRUCTION / ADDITION OR ALTERATION              COMMERCIAL
# 13                    DEMOLITION / DEMOLITION  SINGLE FAMILY / DUPLEX
# 14                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 15                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 16                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 17                               MECHANICAL /  SINGLE FAMILY / DUPLEX
# 18                                 SIDE SEWER  SINGLE FAMILY / DUPLEX
# 19                                   LAND USE             MULTIFAMILY
# 20                                 ELECTRICAL              COMMERCIAL
# 21                                 ELECTRICAL              COMMERCIAL
# 22      CONSTRUCTION / ADDITION OR ALTERATION              COMMERCIAL
# 23                                 ELECTRICAL              COMMERCIAL
# 24      CONSTRUCTION / ADDITION OR ALTERATION  SINGLE FAMILY / DUPLEX
# 25    BOILER / NEW OBJECT OR MONITOR'G CHANGE             MULTIFAMILY
# 26                                 ELECTRICAL             MULTIFAMILY
# 27                                 ELECTRICAL              COMMERCIAL
# 28                                 ELECTRICAL              COMMERCIAL
# 29                                   LAND USE  SINGLE FAMILY / DUPLEX
# 30      CONSTRUCTION / ADDITION OR ALTERATION  SINGLE FAMILY / DUPLEX
# 31      CONSTRUCTION / ADDITION OR ALTERATION              COMMERCIAL
# 32                                 SIDE SEWER  SINGLE FAMILY / DUPLEX
# 33                               MECHANICAL /  SINGLE FAMILY / DUPLEX
# 34                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 35      CONSTRUCTION / ADDITION OR ALTERATION  SINGLE FAMILY / DUPLEX
# 36                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 37                               MECHANICAL /  SINGLE FAMILY / DUPLEX
# 38                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 39      CONSTRUCTION / ADDITION OR ALTERATION  SINGLE FAMILY / DUPLEX
# 40                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 41                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 42                                 SIDE SEWER  SINGLE FAMILY / DUPLEX
# 43      CONSTRUCTION / ADDITION OR ALTERATION  SINGLE FAMILY / DUPLEX
# 44                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 45      CONSTRUCTION / ADDITION OR ALTERATION  SINGLE FAMILY / DUPLEX
# 46                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 47                             SIGN/BILLBOARD              COMMERCIAL
# 48                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 49                                 ELECTRICAL              COMMERCIAL
# 50      CONSTRUCTION / ADDITION OR ALTERATION  SINGLE FAMILY / DUPLEX
# 51      CONSTRUCTION / ADDITION OR ALTERATION  SINGLE FAMILY / DUPLEX
# 52                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 53                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 54                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 55                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 56                                 CONVEYANCE                     NaN
# 57                               MECHANICAL /  SINGLE FAMILY / DUPLEX
# 58                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 59                                 ELECTRICAL              COMMERCIAL
# 60                                 PTS PERMIT                     NaN
# 61                                 SIDE SEWER  SINGLE FAMILY / DUPLEX
# 62                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 63                                        NaN                     NaN
# 64                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 65                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 66                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 67                                 ELECTRICAL  SINGLE FAMILY / DUPLEX
# 68                                        NaN                     NaN
# 69                                        NaN                     NaN
# ...
# 105   BOILER / NEW OBJECT OR MONITOR'G CHANGE              COMMERCIAL
# 106                                CONVEYANCE                     NaN
# 107  MECHANICAL / ALTER EXISTING INSTALLATION              COMMERCIAL
# 108     CONSTRUCTION / ADDITION OR ALTERATION              COMMERCIAL
# 109                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 110                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 111                                ELECTRICAL              COMMERCIAL
# 112   BOILER / NEW OBJECT OR MONITOR'G CHANGE             MULTIFAMILY
# 113                                SIDE SEWER  SINGLE FAMILY / DUPLEX
# 114                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 115     CONSTRUCTION / ADDITION OR ALTERATION              COMMERCIAL
# 116                                ELECTRICAL             MULTIFAMILY
# 117  MECHANICAL / ALTER EXISTING INSTALLATION              COMMERCIAL
# 118                                   BLANKET              COMMERCIAL
# 119                                SIDE SEWER  SINGLE FAMILY / DUPLEX
# 120                   POST ISSUANCE SUBMITTAL  SINGLE FAMILY / DUPLEX
# 121                                ELECTRICAL              COMMERCIAL
# 122                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 123     CONSTRUCTION / ADDITION OR ALTERATION              COMMERCIAL
# 124   BOILER / NEW OBJECT OR MONITOR'G CHANGE  SINGLE FAMILY / DUPLEX
# 125                                ELECTRICAL           INSTITUTIONAL
# 126                              MECHANICAL /  SINGLE FAMILY / DUPLEX
# 127                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 128                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 129     CONSTRUCTION / ADDITION OR ALTERATION  SINGLE FAMILY / DUPLEX
# 130                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 131                                SIDE SEWER  SINGLE FAMILY / DUPLEX
# 132                                ELECTRICAL              COMMERCIAL
# 133     CONSTRUCTION / ADDITION OR ALTERATION  SINGLE FAMILY / DUPLEX
# 134     CONSTRUCTION / ADDITION OR ALTERATION              COMMERCIAL
# 135                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 136                                ELECTRICAL              COMMERCIAL
# 137  MECHANICAL / ALTER EXISTING INSTALLATION              COMMERCIAL
# 138   BOILER / NEW OBJECT OR MONITOR'G CHANGE  SINGLE FAMILY / DUPLEX
# 139                                ELECTRICAL              COMMERCIAL
# 140                              DEMOLITION /  SINGLE FAMILY / DUPLEX
# 141                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 142                                SIDE SEWER  SINGLE FAMILY / DUPLEX
# 143     CONSTRUCTION / ADDITION OR ALTERATION  SINGLE FAMILY / DUPLEX
# 144                                SIDE SEWER              COMMERCIAL
# 145                                SIDE SEWER  SINGLE FAMILY / DUPLEX
# 146                            SIGN/BILLBOARD              COMMERCIAL
# 147     CONSTRUCTION / ADDITION OR ALTERATION             MULTIFAMILY
# 148                                   BLANKET              COMMERCIAL
# 149                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 150                                PTS PERMIT                     NaN
# 151   BOILER / NEW OBJECT OR MONITOR'G CHANGE             MULTIFAMILY
# 152                                CONVEYANCE                     NaN
# 153                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 154                                SIDE SEWER  SINGLE FAMILY / DUPLEX
# 155                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 156                                CONVEYANCE                     NaN
# 157                                       NaN                     NaN
# 158                                ELECTRICAL              COMMERCIAL
# 159                                ELECTRICAL              COMMERCIAL
# 160                                       NaN                     NaN
# 161                                ELECTRICAL           INSTITUTIONAL
# 162                                CONVEYANCE                     NaN
# 163                              MECHANICAL /  SINGLE FAMILY / DUPLEX
# 164                                       NaN                     NaN
# 165   BOILER / NEW OBJECT OR MONITOR'G CHANGE           INSTITUTIONAL
# 166                                ELECTRICAL             MULTIFAMILY
# 167                                SIDE SEWER  SINGLE FAMILY / DUPLEX
# 168                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 169                                       NaN                     NaN
# 170                                       NaN                     NaN
# 171                                ELECTRICAL  SINGLE FAMILY / DUPLEX
# 172                                CONVEYANCE                     NaN
# 173                              MECHANICAL /  SINGLE FAMILY / DUPLEX
# 174                                       NaN                     NaN
# 175                                       NaN                     NaN
# 176                                ELECTRICAL           INSTITUTIONAL
# 177                                       NaN                     NaN
# 178                                       NaN                     NaN
# 179                                       NaN                     NaN
# 180                                       NaN                     NaN
# 181                                       NaN                     NaN
# 182                                       NaN                     NaN
# 183                                       NaN                     NaN
# 184                                       NaN                     NaN
# 185                                       NaN                     NaN
# 186                                       NaN                     NaN
# 187                                       NaN                     NaN
# 188                                       NaN                     NaN
# 189                                       NaN                     NaN
# 190                                       NaN                     NaN
# 191                                       NaN                     NaN
# 192                                       NaN                     NaN
# 193                                       NaN                     NaN
# 194                                       NaN                     NaN
# 195                                       NaN                     NaN
# 196                                       NaN                     NaN
# 197                                       NaN                     NaN
# 198                                       NaN                     NaN
# 199                                       NaN                     NaN
#
#      job_value  has_ld  tf-idf_description
# 0          0.0       0            1.944464
# 1          0.0       0            2.240490
# 2          0.0       0            2.620758
# 3          0.0       0            2.083272
# 4          0.0       0            2.602990
# 5          0.0       0            1.000000
# 6     250000.0       1            2.799645
# 7          0.0       0            1.377901
# 8          0.0       1            1.414076
# 9          0.0       0            1.669762
# 10         0.0       0            1.410228
# 11         0.0       0            1.729264
# 12     45000.0       1            3.301165
# 13         0.0       0            2.129480
# 14         0.0       0            1.378026
# 15         0.0       0            2.517140
# 16         0.0       0            1.702799
# 17         0.0       0            2.330450
# 18         0.0       0            1.908974
# 19         0.0       1            1.729264
# 20         0.0       0            3.108278
# 21         0.0       0            1.412895
# 22    170000.0       1            4.084502
# 23         0.0       0            2.139505
# 24      1000.0       0            3.070862
# 25         0.0       0            1.640491
# 26         0.0       0            1.884571
# 27         0.0       0            2.326732
# 28         0.0       0            2.321862
# 29         0.0       1            2.964933
# 30     60000.0       1            2.866415
# 31     20558.0       1            2.271890
# 32         0.0       0            3.311431
# 33         0.0       0            1.839842
# 34         0.0       0            3.256178
# 35      8000.0       1            2.434005
# 36         0.0       0            2.339861
# 37         0.0       0            1.943749
# 38         0.0       0            2.937852
# 39      4000.0       0            3.249149
# 40         0.0       0            2.683281
# 41         0.0       0            2.316230
# 42         0.0       0            1.413594
# 43    119300.0       1            2.493348
# 44         0.0       0            1.915969
# 45    190000.0       0            4.574784
# 46         0.0       0            3.220609
# 47         0.0       0            2.967156
# 48         0.0       0            1.727664
# 49         0.0       0            1.411078
# 50     55000.0       0            3.940076
# 51      3777.0       0            3.064270
# 52         0.0       0            3.007737
# 53         0.0       0            1.718972
# 54         0.0       0            2.155358
# 55         0.0       0            1.728293
# 56         0.0       0            2.704942
# 57         0.0       0            1.995563
# 58         0.0       0            2.163233
# 59         0.0       0            2.412186
# 60         0.0       1            3.002104
# 61         0.0       0            1.413594
# 62         0.0       0            1.944464
# 63         0.0       0            3.195211
# 64         0.0       0            2.116130
# 65         0.0       0            2.407681
# 66         0.0       0            1.999897
# 67         0.0       0            2.225021
# 68         0.0       0            2.789960
# 69         0.0       0            3.283908
# 70         0.0       0            2.699026
# 71         0.0       0            3.173906
# 72         0.0       0            2.990347
# 73         0.0       0            3.160716
# 74         0.0       0            2.754667
# 75         0.0       0            3.558921
# 76         0.0       0            3.207132
# 77         0.0       0            2.196264
# 78         0.0       0            3.077607
# 79         0.0       0            3.117723
# 80         0.0       0            2.703180
# 81         0.0       0            3.455951
# 82         0.0       0            2.033160
# 83         0.0       0            2.649213
# 84         0.0       0            1.922489
# 85         0.0       0            2.745705
# 86         0.0       0            3.047379
# 87         0.0       0            1.995064
# 88         0.0       0            2.091918
# 89         0.0       0            2.384654
# 90         0.0       0            1.815897
# 91         0.0       0            2.137136
# 92         0.0       0            1.000000
# 93         0.0       0            2.470726
# 94         0.0       0            3.503225
# 95         0.0       0            1.805701
# 96         0.0       0            2.665892
# 97         0.0       0            1.274943
# 98         0.0       0            1.886059
# 99         0.0       0            1.378499
# 100        0.0       0            2.066037
# 101    20000.0       1            3.449173
# 102        0.0       0            2.941935
# 103        0.0       0            1.680537
# 104        0.0       0            2.083272
# 105        0.0       0            1.380524
# 106        0.0       0            2.730349
# 107        0.0       0            2.709357
# 108   136000.0       0            3.286962
# 109        0.0       0            1.526010
# 110        0.0       0            3.554674
# 111        0.0       0            1.398731
# 112        0.0       0            2.716072
# 113        0.0       0            1.692555
# 114        0.0       0            2.564075
# 115    20000.0       1            2.210897
# 116        0.0       0            3.740991
# 117        0.0       0            2.163306
# 118        0.0       1            2.675731
# 119        0.0       0            2.601298
# 120        0.0       1            2.014014
# 121        0.0       0            1.712711
# 122        0.0       0            1.654067
# 123    20000.0       1            3.558370
# 124        0.0       0            1.889408
# 125        0.0       0            1.725983
# 126        0.0       0            2.186389
# 127        0.0       0            2.742985
# 128        0.0       0            2.633916
# 129    23339.0       0            3.614723
# 130        0.0       0            2.222622
# 131        0.0       0            1.413594
# 132        0.0       0            2.346189
# 133    50000.0       0            3.500738
# 134   600000.0       1            2.716049
# 135        0.0       0            2.685112
# 136        0.0       0            1.939860
# 137        0.0       0            2.386916
# 138        0.0       0            1.380524
# 139        0.0       0            1.483593
# 140        0.0       0            3.019120
# 141        0.0       0            2.688026
# 142        0.0       0            1.605453
# 143    17976.0       0            2.319121
# 144        0.0       0            1.659887
# 145        0.0       0            1.000000
# 146        0.0       0            2.838452
# 147        0.0       1            2.893337
# 148        0.0       1            2.742238
# 149        0.0       0            3.773648
# 150        0.0       1            2.853380
# 151        0.0       0            1.858485
# 152        0.0       0            1.977842
# 153        0.0       0            2.224488
# 154        0.0       0            1.413594
# 155        0.0       0            2.803248
# 156        0.0       0            1.672957
# 157        0.0       0            3.118093
# 158        0.0       0            2.220370
# 159        0.0       0            2.174320
# 160        0.0       0            3.566660
# 161        0.0       0            1.840863
# 162        0.0       0            2.668335
# 163        0.0       0            1.718692
# 164        0.0       0            2.108238
# 165        0.0       0            1.413566
# 166        0.0       0            2.093832
# 167        0.0       0            1.691574
# 168        0.0       0            2.385920
# 169        0.0       0            3.643829
# 170        0.0       0            0.000000
# 171        0.0       0            1.979367
# 172        0.0       0            1.468009
# 173        0.0       0            2.709800
# 174        0.0       0            3.488719
# 175        0.0       0            3.690171
# 176        0.0       0            2.162305
# 177        0.0       0            3.387021
# 178        0.0       0            3.394036
# 179        0.0       0            2.475335
# 180        0.0       0            3.787836
# 181        0.0       0            3.081658
# 182        0.0       0            2.888768
# 183        0.0       0            2.995050
# 184        0.0       0            3.092820
# 185        0.0       0            2.954480
# 186        0.0       0            3.778858
# 187        0.0       0            3.140373
# 188        0.0       0            2.592336
# 189        0.0       0            3.001119
# 190        0.0       0            3.538669
# 191        0.0       0            3.517993
# 192        0.0       0            2.864883
# 193        0.0       0            2.692185
# 194        0.0       0            2.930322
# 195        0.0       0            1.860010
# 196        0.0       0            3.031414
# 197        0.0       0            2.930322
# 198        0.0       0            2.102156
# 199        0.0       0            3.667293

# %%
X_train.dtypes
# Out:
# licensetype            object
# businessname           object
# legaldescription       object
# description            object
# type                   object
# subtype                object
# job_value             float64
# has_ld                  int64
# tf-idf_description    float64
# dtype: object
